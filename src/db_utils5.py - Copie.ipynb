# %%
import pandas as pd
import numpy as np

print("OK projet prêt")
# Out:
# OK projet prêt

# %%
import pandas as pd

patients = pd.read_csv("../data/raw/patients.csv")
encounters = pd.read_csv("../data/raw/encounters.csv")
conditions = pd.read_csv("../data/raw/conditions.csv")
procedures = pd.read_csv("../data/raw/procedures.csv")

patients.head()
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  ca73401b-6e45-ae91-4a1d-04b9ccc7fcb6  1992-03-06       NaN  999-43-7332
# 1  5939ede0-f907-8988-0403-fe4156a20af5  1978-12-29       NaN  999-94-3774
# 2  0b8736b7-6317-9207-f29a-77a96272dcca  2020-08-30       NaN  999-84-9012
# 3  ef6331b4-9a11-2a21-1c7d-33d8e6514514  2014-11-29       NaN  999-61-7060
# 4  694843af-4a43-36ef-6b50-1a071e8ee563  2023-05-17       NaN  999-20-8860
#
#      DRIVERS    PASSPORT PREFIX        FIRST      MIDDLE             LAST  \
# 0  S99964956  X35591422X    Mr.     Kenny207         NaN       Pfeffer420
# 1  S99938470  X12961477X    Mr.    Dillon740  Roberto515  Christiansen251
# 2        NaN         NaN    NaN  Courtney281  Chantay958       Ruecker817
# 3        NaN         NaN    NaN     Elvis145  Ulysses632       Fritsch593
# 4        NaN         NaN    NaN  Fernanda589   Elmira442         Rogahn59
#
#    ...        CITY          STATE            COUNTY     FIPS   ZIP        LAT  \
# 0  ...      Boston  Massachusetts    Suffolk County  25025.0  2136  42.346033
# 1  ...      Ludlow  Massachusetts    Hampden County      NaN     0  42.187863
# 2  ...  Wilmington  Massachusetts  Middlesex County  25017.0  1887  42.573080
# 3  ...   Lancaster  Massachusetts  Worcester County      NaN     0  42.478965
# 4  ...    Plymouth  Massachusetts   Plymouth County  25023.0  2360  41.946438
#
#          LON HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  INCOME
# 0 -71.085493             6610.53            70513.90    6394
# 1 -72.427241            87541.60             1629.01   99861
# 2 -71.167521            18748.52             1053.22  129382
# 3 -71.688491            21678.55                0.00  128384
# 4 -70.654003            21819.99            13699.13  101630
#
# [5 rows x 28 columns]
